# %% [markdown]
# <a href="https://colab.research.google.com/github/dklpp/tf-developer/blob/main/C3_W3_sarcasm_with_bi_LSTM_and_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/https-deeplearning-ai/tensorflow-1-public/blob/master/C3/W3/ungraded_labs/C3_W3_Lab_5_sarcasm_with_bi_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Training a Sarcasm Detection Model using Bidirectional LSTMs
#
# In this lab, you will revisit the [News Headlines Dataset for Sarcasm Detection](https://www.kaggle.com/rmisra/news-headlines-dataset-for-sarcasm-detection/home) dataset and use it to train a Bi-LSTM Model.

# %% [markdown]
# ## Download the Dataset
#
# First, you will download the JSON file and extract the contents into lists.

# %%
# Download the dataset
# !wget https://storage.googleapis.com/tensorflow-1-public/course3/sarcasm.json
# Out:
# --2023-11-27 13:39:13--  https://storage.googleapis.com/tensorflow-1-public/course3/sarcasm.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.4.207, 142.251.10.207, 142.251.12.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.4.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5643545 (5.4M) [application/json]
# Saving to: ‘sarcasm.json’
#
# sarcasm.json        100%[===================>]   5.38M  4.86MB/s    in 1.1s
#
# 2023-11-27 13:39:15 (4.86 MB/s) - ‘sarcasm.json’ saved [5643545/5643545]

# %%
import json

# Load the JSON file
with open("./sarcasm.json", 'r') as f:
    datastore = json.load(f)

# Initialize the lists
sentences = []
labels = []

# Collect sentences and labels into the lists
for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

# %% [markdown]
# ## Split the Dataset
#
# You will then split the lists into train and test sets.

# %%
training_size = 20000

# Split the sentences
training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]

# Split the labels
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

# %% [markdown]
# ## Data preprocessing
#
# Next, you will generate the vocabulary and padded sequences.

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

vocab_size = 10000
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"

# Initialize the Tokenizer class
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)

# Generate the word index dictionary
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index

# Generate and pad the training sequences
training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Generate and pad the testing sequences
testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Convert the labels lists into numpy arrays
training_labels = np.array(training_labels)
testing_labels = np.array(testing_labels)

# %% [markdown]
# ## Build and Compile the Model with LSTM
#
# The architecture here is almost identical to the one you used in the previous lab with the IMDB Reviews. Try to tweak the parameters and see how it affects the training time and accuracy (both training and validation).

# %%
import tensorflow as tf

# Parameters
embedding_dim = 16
lstm_dim = 32
dense_dim = 24

# Model Definition with LSTM
model_lstm = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(lstm_dim)),
    tf.keras.layers.Dense(dense_dim, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Set the training parameters
model_lstm.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# Print the model summary
model_lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 120, 16)           160000
#
#  bidirectional (Bidirection  (None, 64)                12544
#  al)
#
#  dense (Dense)               (None, 24)                1560
#
#  dense_1 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 174129 (680.19 KB)
# Trainable params: 174129 (680.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Train the Model

# %%
NUM_EPOCHS = 10

# Train the model
history_lstm = model_lstm.fit(training_padded, training_labels, epochs=NUM_EPOCHS, validation_data=(testing_padded, testing_labels))
# Out:
# Epoch 1/10
# 625/625 [==============================] - 36s 42ms/step - loss: 0.4211 - accuracy: 0.7883 - val_loss: 0.3293 - val_accuracy: 0.8585
# Epoch 2/10
# 625/625 [==============================] - 10s 16ms/step - loss: 0.2203 - accuracy: 0.9090 - val_loss: 0.3582 - val_accuracy: 0.8444
# Epoch 3/10
# 625/625 [==============================] - 8s 13ms/step - loss: 0.1442 - accuracy: 0.9449 - val_loss: 0.4005 - val_accuracy: 0.8536
# Epoch 4/10
# 625/625 [==============================] - 9s 15ms/step - loss: 0.0903 - accuracy: 0.9692 - val_loss: 0.4885 - val_accuracy: 0.8456
# Epoch 5/10
# 625/625 [==============================] - 9s 14ms/step - loss: 0.0567 - accuracy: 0.9811 - val_loss: 0.5662 - val_accuracy: 0.8360
# Epoch 6/10
# 625/625 [==============================] - 9s 14ms/step - loss: 0.0380 - accuracy: 0.9877 - val_loss: 0.7206 - val_accuracy: 0.8365
# Epoch 7/10
# 625/625 [==============================] - 9s 15ms/step - loss: 0.0228 - accuracy: 0.9926 - val_loss: 0.7817 - val_accuracy: 0.8389
# Epoch 8/10
# 625/625 [==============================] - 9s 15ms/step - loss: 0.0183 - accuracy: 0.9944 - val_loss: 0.8975 - val_accuracy: 0.8302
# Epoch 9/10
# 625/625 [==============================] - 9s 15ms/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.8851 - val_accuracy: 0.8346
# Epoch 10/10
# 625/625 [==============================] - 9s 14ms/step - loss: 0.0114 - accuracy: 0.9958 - val_loss: 1.0066 - val_accuracy: 0.8304

# %%
import matplotlib.pyplot as plt

# Plot Utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# Plot the accuracy and loss history
plot_graphs(history_lstm, 'accuracy')
plot_graphs(history_lstm, 'loss')

# %% [markdown]
# ## Build and Compile the Model with CNN

# %%
import tensorflow as tf

# Parameters
embedding_dim = 16
filters = 128
kernel_size = 5
dense_dim = 6

# Model Definition with Conv1D
model_conv = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(filters, kernel_size, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(dense_dim, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Set the training parameters
model_conv.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# Print the model summary
model_conv.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 120, 16)           160000
#
#  conv1d (Conv1D)             (None, 116, 128)          10368
#
#  global_max_pooling1d (Glob  (None, 128)               0
#  alMaxPooling1D)
#
#  dense_2 (Dense)             (None, 6)                 774
#
#  dense_3 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 171149 (668.55 KB)
# Trainable params: 171149 (668.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
NUM_EPOCHS = 10

# Train the model
history_conv = model_conv.fit(training_padded, training_labels, epochs=NUM_EPOCHS, validation_data=(testing_padded, testing_labels))
# Out:
# Epoch 1/10
# 625/625 [==============================] - 17s 18ms/step - loss: 0.4598 - accuracy: 0.7636 - val_loss: 0.3648 - val_accuracy: 0.8399
# Epoch 2/10
# 625/625 [==============================] - 4s 6ms/step - loss: 0.2388 - accuracy: 0.9006 - val_loss: 0.3645 - val_accuracy: 0.8484
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1321 - accuracy: 0.9531 - val_loss: 0.4238 - val_accuracy: 0.8414
# Epoch 4/10
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0612 - accuracy: 0.9814 - val_loss: 0.5399 - val_accuracy: 0.8396
# Epoch 5/10
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0247 - accuracy: 0.9936 - val_loss: 0.6630 - val_accuracy: 0.8386
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.0093 - accuracy: 0.9977 - val_loss: 0.7726 - val_accuracy: 0.8344
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.0043 - accuracy: 0.9991 - val_loss: 0.8510 - val_accuracy: 0.8356
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.9318 - val_accuracy: 0.8332
# Epoch 9/10
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 1.0073 - val_accuracy: 0.8326
# Epoch 10/10
# 625/625 [==============================] - 3s 6ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 1.0530 - val_accuracy: 0.8343

# %%
import matplotlib.pyplot as plt

# Plot the accuracy and loss history
plot_graphs(history_conv, 'accuracy')
plot_graphs(history_conv, 'loss')
